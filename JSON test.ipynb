# %%
import pandas as pd
import re

# %%
texts = pd.read_json('/content/drive/My Drive/Colab Datasets/JSON_texts/')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-3-6dda159883e1> in <module>()
# ----> 1 texts = pd.read_json('/content/drive/My Drive/Colab Datasets/JSON_texts/')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     584         lines=lines,
#     585         chunksize=chunksize,
# --> 586         compression=compression,
#     587     )
#     588
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     648                 raise ValueError("chunksize can only be passed if lines=True")
# ...
