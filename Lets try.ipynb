# %%
import nltk
import random
import string
import numpy as np
import pandas as pd
import json
import re, string, unicodedata
import spacy
nlp = spacy.load('en')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from collections import defaultdict
import warnings
warnings.filterwarnings("ignore")
nltk.download('punkt') 
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
from sklearn.metrics import jaccard_similarity_score
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# with open('/content/drive/My Drive/Colab Datasets/COVID Chat Bot/answers.json', 'r') as f:
#   answers = json.load(f)

# with open('/content/drive/My Drive/Colab Datasets/COVID Chat Bot/questions.json', 'r') as f:
#   questions = json.load(f)

# with open('/content/drive/My Drive/Colab Datasets/COVID Chat Bot/dictionary.json', 'r') as f:
#   dictionary = json.load(f)

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Datasets/COVID Chat Bot/cdc_qa.csv')
df.columns = ['Questions', 'Answers']

# %%
df.head(5)
# Out:
#                                            Questions                                            Answers
# 0                       What is a novel coronavirus?  A novel coronavirus is a new coronavirus that ...
# 1  Why is the disease being called coronavirus di...  On February 11, 2020 the World Health Organiza...
# 2  Why might someone blame or avoid individuals a...  People in the U.S. may be worried or anxious a...
# 3  How can people help stop stigma related to COV...  People can fight stigma and help, not hurt, ot...
# 4                   What is the source of the virus?  Coronaviruses are a large family of viruses. S...

# %%
vectorizer = CountVectorizer()

# %%
count_vec = vectorizer.fit_transform(df.Questions).toarray()

# %%
sample_question = ['Should I keep my kids home from school?']

# %%
test = vectorizer.transform(sample_question).toarray()

# %%
df['similarity'] = cosine_similarity(count_vec, test)

# %%
df.sort_values(['similarity'], ascending=False)

# %%
print(df.sort_values(['similarity'], ascending=False).iloc[0]['Answers'])

# %%
user_input = input('What would you like to ask me?\n')
test = vectorizer.transform([user_input]).toarray()
df['similarity'] = cosine_similarity(count_vec, test)
print(df.sort_values(['similarity'], ascending=False).iloc[0]['Answers'])
# Out:
# What would you like to ask me?
# What is coronavirus?
# A novel coronavirus is a new coronavirus that has not been previously identified. The virus causing coronavirus disease 2019 (COVID-19), is not the same as the coronaviruses that commonly circulate among humans and cause mild illness, like the common cold.
# A diagnosis with coronavirus 229E, NL63, OC43, or HKU1 is not the same as a COVID-19 diagnosis. Patients with COVID-19 will be evaluated and cared for differently than patients with common coronavirus diagnosis.

# %%
[user_input]
# Out:
# ['What is your name?']

# %% [markdown]
# try Jaccard Similarity to account for misspelling

# %%
df['similarity'] = jaccard_similarity_score(test, count_vec)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-643780cd3924> in <module>()
# ----> 1 df['similarity'] = jaccard_similarity_score(test, count_vec)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in jaccard_similarity_score(y_true, y_pred, normalize, sample_weight)
#     665
#     666     # Compute accuracy for each possible representation
# --> 667     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     668     check_consistent_length(y_true, y_pred, sample_weight)
#     669     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
# ...

# %%
similarity = jaccard_similarity_score(sample_question, df.iloc[0]['Questions'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-98ef71515ac2> in <module>()
# ----> 1 similarity = jaccard_similarity_score(sample_question, df.iloc[0]['Questions'])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in jaccard_similarity_score(y_true, y_pred, normalize, sample_weight)
#     665
#     666     # Compute accuracy for each possible representation
# --> 667     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     668     check_consistent_length(y_true, y_pred, sample_weight)
#     669     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
# ...

# %%
for question in df['Questions']:
  df['similarity'] = jaccard_similarity_score(sample_question, question)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d4662c832ebb> in <module>()
#       1 for question in df['Questions']:
# ----> 2   df['similarity'] = jaccard_similarity_score(sample_question, question)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in jaccard_similarity_score(y_true, y_pred, normalize, sample_weight)
#     665
#     666     # Compute accuracy for each possible representation
# --> 667     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     668     check_consistent_length(y_true, y_pred, sample_weight)
#     669     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
# ...

# %%
jac_score = jaccard_score(sample_question, df['Questions'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-21063f9fcd16> in <module>()
# ----> 1 jac_score = jaccard_score(sample_question, df['Questions'])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in jaccard_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#     791     """
#     792     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# --> 793                                     pos_label)
#     794     samplewise = average == 'samples'
#     795     MCM = multilabel_confusion_matrix(y_true, y_pred,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1299                          str(average_options))
#    1300
# -> 1301     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...

# %%
def jaccard_similarity(list_1, list_2):
  s1 = set(list_1)
  s2 = set(list_2)
  return len(s1.intersection(s2)) / len(s1.union(s2))

# %%
list_1 = ['What','are','you','doing']
list_2 = ['How','are','you','doing']

# %%
s1 = set(list_1)
s2 = set(list_2)

# %%
test2 = [1,1,1,2,2,2,3,3,3]

# %%
set(test2)
# Out:
# {1, 2, 3}

# %%
s1.intersection(s2)
# Out:
# {'are', 'doing', 'you'}

# %%
s1.union(s2)
# Out:
# {'How', 'What', 'are', 'doing', 'you'}
